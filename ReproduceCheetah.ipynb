# %%
"""
Launcher for experiments with PEARL

"""
import os
import pathlib
import numpy as np
import click
import json
import torch

from rlkit.envs import ENVS
from rlkit.envs.wrappers import NormalizedBoxEnv
from rlkit.torch.sac.policies import TanhGaussianPolicy
from rlkit.torch.networks import FlattenMlp, MlpEncoder, RecurrentEncoder
from rlkit.torch.sac.sac import PEARLSoftActorCritic
from rlkit.torch.sac.agent import PEARLAgent
from rlkit.launchers.launcher_util import setup_logger
import rlkit.torch.pytorch_util as ptu
from configs.default import default_config



import sys
sys.path.append("/home/user/anaconda3/envs/pearl/lib/python3.5/site-packages")
print(sys.path)
import gym
# Out:
# ['mujoco_env.py', 'ant_dir.py', 'assets', 'ant_goal.py', 'half_cheetah_vel.py', 'half_cheetah.py', 'wrappers.py', 'ant.py', 'ant_multitask_base.py', '__init__.py', '__pycache__', 'humanoid_dir.py', 'trash']
# mujoco_env.py
# mujoco_env
# ant_dir.py
# ant_dir
# assets
# ant_goal.py
# ant_goal
# half_cheetah_vel.py
# half_cheetah_vel
# half_cheetah.py
# half_cheetah
# wrappers.py
# wrappers
# ant.py
# ant
# ant_multitask_base.py
# ant_multitask_base
# __init__.py
# __pycache__
# humanoid_dir.py
# humanoid_dir
# trash
# ['/home/user/Dokumente/#master/Sem_03/ALDR/git/tum-adlr-ws20-08/papers/oyster', '/home/user/anaconda3/lib/python38.zip', '/home/user/anaconda3/lib/python3.8', '/home/user/anaconda3/lib/python3.8/lib-dynload', '', '/home/user/.local/lib/python3.8/site-packages', '/home/user/anaconda3/lib/python3.8/site-packages', '/home/user/Dokumente/#master/Sem_03/ALDR/nbdev', '/home/user/.local/lib/python3.8/site-packages/IPython/extensions', '/home/user/.ipython', '/home/user/anaconda3/envs/pearl/lib/python3.5/site-packages', '/home/user/anaconda3/envs/pearl/lib/python3.5/site-packages', '/home/user/anaconda3/envs/pearl/lib/python3.5/site-packages', '/home/user/anaconda3/envs/pearl/lib/python3.5/site-packages']

# %%
def experiment(variant):

    # create multi-task environment and sample tasks
    env = NormalizedBoxEnv(ENVS[variant['env_name']](**variant['env_params']))
    tasks = env.get_all_task_idx()
    obs_dim = int(np.prod(env.observation_space.shape))
    action_dim = int(np.prod(env.action_space.shape))
    reward_dim = 1

    # instantiate networks
    latent_dim = variant['latent_size']
    context_encoder_input_dim = 2 * obs_dim + action_dim + reward_dim if variant['algo_params']['use_next_obs_in_context'] else obs_dim + action_dim + reward_dim
    context_encoder_output_dim = latent_dim * 2 if variant['algo_params']['use_information_bottleneck'] else latent_dim
    net_size = variant['net_size']
    recurrent = variant['algo_params']['recurrent']
    encoder_model = RecurrentEncoder if recurrent else MlpEncoder

    context_encoder = encoder_model(
        hidden_sizes=[200, 200, 200],
        input_size=context_encoder_input_dim,
        output_size=context_encoder_output_dim,
    )
    qf1 = FlattenMlp(
        hidden_sizes=[net_size, net_size, net_size],
        input_size=obs_dim + action_dim + latent_dim,
        output_size=1,
    )
    qf2 = FlattenMlp(
        hidden_sizes=[net_size, net_size, net_size],
        input_size=obs_dim + action_dim + latent_dim,
        output_size=1,
    )
    vf = FlattenMlp(
        hidden_sizes=[net_size, net_size, net_size],
        input_size=obs_dim + latent_dim,
        output_size=1,
    )
    policy = TanhGaussianPolicy(
        hidden_sizes=[net_size, net_size, net_size],
        obs_dim=obs_dim + latent_dim,
        latent_dim=latent_dim,
        action_dim=action_dim,
    )
    agent = PEARLAgent(
        latent_dim,
        context_encoder,
        policy,
        zIsZeros=False,
        **variant['algo_params']
    )
    algorithm = PEARLSoftActorCritic(
        env=env,
        train_tasks=list(tasks[:variant['n_train_tasks']]),
        eval_tasks=list(tasks[-variant['n_eval_tasks']:]),
        nets=[agent, qf1, qf2, vf],
        latent_dim=latent_dim,
        **variant['algo_params']
    )

    # optionally load pre-trained weights
    if variant['path_to_weights'] is not None:
        path = variant['path_to_weights']
        context_encoder.load_state_dict(torch.load(os.path.join(path, 'context_encoder.pth')))
        qf1.load_state_dict(torch.load(os.path.join(path, 'qf1.pth')))
        qf2.load_state_dict(torch.load(os.path.join(path, 'qf2.pth')))
        vf.load_state_dict(torch.load(os.path.join(path, 'vf.pth')))
        # TODO hacky, revisit after model refactor
        algorithm.networks[-2].load_state_dict(torch.load(os.path.join(path, 'target_vf.pth')))
        policy.load_state_dict(torch.load(os.path.join(path, 'policy.pth')))

    # optional GPU mode
    ptu.set_gpu_mode(variant['util_params']['use_gpu'], variant['util_params']['gpu_id'])
    if ptu.gpu_enabled():
        algorithm.to()

    # debugging triggers a lot of printing and logs to a debug directory
    DEBUG = variant['util_params']['debug']
    os.environ['DEBUG'] = str(int(DEBUG))

    # create logging directory
    # TODO support Docker
    exp_id = 'debug' if DEBUG else None
    experiment_log_dir = setup_logger(variant['env_name'], variant=variant, exp_id=exp_id, base_log_dir=variant['util_params']['base_log_dir'])

    # optionally save eval trajectories as pkl files
    if variant['algo_params']['dump_eval_paths']:
        pickle_dir = experiment_log_dir + '/eval_trajectories'
        pathlib.Path(pickle_dir).mkdir(parents=True, exist_ok=True)

    # run the algorithm
    algorithm.train()

# %%
def deep_update_dict(fr, to):
    ''' update dict of dicts with new values '''
    # assume dicts have same keys
    for k, v in fr.items():
        if type(v) is dict:
            deep_update_dict(v, to[k])
        else:
            to[k] = v
    return to

# %%
def main(config, gpu, docker, debug):

    variant = default_config
    if config:
        with open(os.path.join(config)) as f:
            exp_params = json.load(f)
        variant = deep_update_dict(exp_params, variant)
    variant['util_params']['gpu_id'] = gpu

    experiment(variant)

# %%
main(config='./configs/cheetah-vel.json', gpu=False, docker=False, debug=False)
# Out:
# hello
# <HalfCheetahVelEnv instance>
# [1. 1. 1. 1. 1. 1.]
# Box(-1.0, 1.0, (6,), float32)
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 20
# 6
# 2020-12-29 16:35:15.335343 CET | Variant:
# 2020-12-29 16:35:15.336904 CET | {
#   "env_name": "cheetah-vel",
#   "n_train_tasks": 100,
#   "n_eval_tasks": 30,
#   "latent_size": 5,
#   "net_size": 300,
#   "path_to_weights": null,
#   "env_params": {
#     "n_tasks": 130,
#     "randomize_tasks": true
#   },
#   "algo_params": {
#     "meta_batch": 16,
#     "num_iterations": 500,
#     "num_initial_steps": 2000,
#     "num_tasks_sample": 5,
#     "num_steps_prior": 400,
#     "num_steps_posterior": 0,
#     "num_extra_rl_steps_posterior": 600,
#     "num_train_steps_per_itr": 2000,
#     "num_evals": 1,
#     "num_steps_per_eval": 600,
#     "batch_size": 256,
#     "embedding_batch_size": 100,
#     "embedding_mini_batch_size": 100,
#     "max_path_length": 200,
#     "discount": 0.99,
#     "soft_target_tau": 0.005,
#     "policy_lr": 0.0003,
#     "qf_lr": 0.0003,
#     "vf_lr": 0.0003,
#     "context_lr": 0.0003,
#     "reward_scale": 5.0,
#     "sparse_rewards": false,
#     "kl_lambda": 0.1,
#     "use_information_bottleneck": true,
#     "use_next_obs_in_context": false,
#     "update_post_train": 1,
#     "num_exp_traj_eval": 2,
#     "recurrent": false,
#     "dump_eval_paths": false
#   },
#   "util_params": {
#     "base_log_dir": "output",
#     "use_gpu": false,
#     "gpu_id": false,
#     "debug": false,
#     "docker": false
#   }
# }
# /home/user/anaconda3/envs/pearl/lib/python3.5/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# HBox(children=(FloatProgress(value=0.0, description='Total Iterations', max=500.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Train Tasks', max=5.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Train Step', max=2000.0, style=ProgressStyle(description_…
# collecting initial pool of data for train and eval
# fixed z:  False
# /home/user/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py:130: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   Variable._execution_engine.run_backward(
# [-274.0129071805964]
# ----------------------------------  ----------------
# Z mean train                             0.00272045
# Z variance train                         0.00694189
# KL Divergence                          159.084
# KL Loss                                 15.9084
# QF Loss                                138.917
# VF Loss                                 16.24
# Policy Loss                             -3.99314
# Q Predictions Mean                      -0.00578031
# Q Predictions Std                        0.00204433
# Q Predictions Max                        0.00215009
# Q Predictions Min                       -0.0128725
# V Predictions Mean                      -0.00192036
# V Predictions Std                        0.00213404
# V Predictions Max                        0.00473923
# V Predictions Min                       -0.00879124
# Log Pis Mean                            -4.01894
# Log Pis Std                              0.528611
# Log Pis Max                             -2.09103
# Log Pis Min                             -5.65032
# Policy mu Mean                           0.000719302
# Policy mu Std                            0.000873992
# Policy mu Max                            0.00472553
# Policy mu Min                           -0.00214724
# Policy log std Mean                     -0.000422265
# Policy log std Std                       0.00123421
# Policy log std Max                       0.00356294
# Policy log std Min                      -0.0041662
# Z mean eval                              0.162543
# Z variance eval                          0.0532579
# AverageTrainReturn_all_train_tasks    -286.964
# AverageReturn_all_train_tasks         -287.246
# AverageReturn_all_test_tasks          -274.013
# Number of train steps total           2000
# Number of env steps total           205000
# Number of rollouts total                 0
# Train Time (s)                        2135.91
# (Previous) Eval Time (s)                 0
# Sample Time (s)                        479.293
# Epoch Time (s)                        2615.21
# Total Train Time (s)                  2783.39
# Epoch                                    0
# ----------------------------------  ----------------
# 2020-12-29 17:21:38.864868 CET | [2020_12_29_16_35_15] Iteration #0 | Epoch Duration: 2783.2655115127563
# 2020-12-29 17:21:38.870552 CET | [2020_12_29_16_35_15] Iteration #0 | Started Training: True
# [-274.0129071805964, -230.5835926598467]
# ----------------------------------  --------------
# Z mean train                             0.262631
# Z variance train                         0.484535
# KL Divergence                           49.1085
# KL Loss                                  4.91085
# QF Loss                                 22.6836
# VF Loss                                  4.04963
# Policy Loss                             31.3194
# Q Predictions Mean                     -35.7886
# Q Predictions Std                       24.5224
# Q Predictions Max                       -1.78727
# Q Predictions Min                     -120.816
# V Predictions Mean                     -30.5893
# V Predictions Std                       23.4928
# V Predictions Max                        0.0186598
# V Predictions Min                     -112.305
# Log Pis Mean                            -3.25259
# Log Pis Std                              1.20679
# Log Pis Max                              1.46736
# Log Pis Min                             -9.11326
# Policy mu Mean                           0.170555
# Policy mu Std                            0.388946
# Policy mu Max                            1.6444
# Policy mu Min                           -1.25026
# Policy log std Mean                     -0.268415
# Policy log std Std                       0.0993214
# Policy log std Max                      -0.0652476
# Policy log std Min                      -0.654149
# Z mean eval                              0.231152
# Z variance eval                          0.0691936
# AverageTrainReturn_all_train_tasks    -240.568
# AverageReturn_all_train_tasks         -252.31
# AverageReturn_all_test_tasks          -230.584
# Number of train steps total           4000
# Number of env steps total           210000
# Number of rollouts total                 0
# Train Time (s)                        2211.75
# (Previous) Eval Time (s)               168.038
# Sample Time (s)                         16.5239
# Epoch Time (s)                        2396.31
# Total Train Time (s)                  5179.83
# Epoch                                    1
# ----------------------------------  --------------
# 2020-12-29 18:01:35.280542 CET | [2020_12_29_16_35_15] Iteration #1 | Epoch Duration: 2396.3984882831573
# 2020-12-29 18:01:35.283236 CET | [2020_12_29_16_35_15] Iteration #1 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428]
# ----------------------------------  --------------
# Z mean train                             0.0797069
# Z variance train                         0.594328
# KL Divergence                           56.6584
# KL Loss                                  5.66584
# QF Loss                                 39.2042
# VF Loss                                  7.40086
# Policy Loss                             61.6835
# Q Predictions Mean                     -68.0498
# Q Predictions Std                       59.3944
# Q Predictions Max                        0.0262094
# Q Predictions Min                     -244.159
# V Predictions Mean                     -62.1611
# V Predictions Std                       58.2502
# V Predictions Max                        5.20144
# V Predictions Min                     -233.633
# Log Pis Mean                            -2.40957
# Log Pis Std                              2.03039
# Log Pis Max                              7.11634
# Log Pis Min                             -9.65902
# Policy mu Mean                           0.0520645
# Policy mu Std                            0.601451
# Policy mu Max                            1.87722
# Policy mu Min                           -2.31768
# Policy log std Mean                     -0.302473
# Policy log std Std                       0.13587
# Policy log std Max                       0.221334
# Policy log std Min                      -0.818941
# Z mean eval                              0.145337
# Z variance eval                          0.082947
# AverageTrainReturn_all_train_tasks    -219.874
# AverageReturn_all_train_tasks         -219.919
# AverageReturn_all_test_tasks          -253.698
# Number of train steps total           6000
# Number of env steps total           215000
# Number of rollouts total                 0
# Train Time (s)                        2293.17
# (Previous) Eval Time (s)               168.133
# Sample Time (s)                         16.6643
# Epoch Time (s)                        2477.97
# Total Train Time (s)                  7624.17
# Epoch                                    2
# ----------------------------------  --------------
# 2020-12-29 18:42:19.624724 CET | [2020_12_29_16_35_15] Iteration #2 | Epoch Duration: 2444.3375911712646
# 2020-12-29 18:42:19.630325 CET | [2020_12_29_16_35_15] Iteration #2 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003]
# ----------------------------------  --------------
# Z mean train                             0.313447
# Z variance train                         0.594855
# KL Divergence                           56.1461
# KL Loss                                  5.61461
# QF Loss                                 50.544
# VF Loss                                  7.85243
# Policy Loss                             75.4784
# Q Predictions Mean                     -82.9816
# Q Predictions Std                       75.0219
# Q Predictions Max                        0.163321
# Q Predictions Min                     -302.345
# V Predictions Mean                     -76.1257
# V Predictions Std                       73.5962
# V Predictions Max                        4.91966
# V Predictions Min                     -289.622
# Log Pis Mean                            -2.0018
# Log Pis Std                              2.20553
# Log Pis Max                              8.3106
# Log Pis Min                             -9.44448
# Policy mu Mean                           0.0569239
# Policy mu Std                            0.650007
# Policy mu Max                            2.29481
# Policy mu Min                           -2.4233
# Policy log std Mean                     -0.35407
# Policy log std Std                       0.195993
# Policy log std Max                       0.221035
# Policy log std Min                      -1.15144
# Z mean eval                              0.101555
# Z variance eval                          0.0695711
# AverageTrainReturn_all_train_tasks    -202.042
# AverageReturn_all_train_tasks         -161.236
# AverageReturn_all_test_tasks          -150.448
# Number of train steps total           8000
# Number of env steps total           220000
# Number of rollouts total                 0
# Train Time (s)                        2101.4
# (Previous) Eval Time (s)               134.503
# Sample Time (s)                         13.0179
# Epoch Time (s)                        2248.92
# Total Train Time (s)                  9899.53
# Epoch                                    3
# ----------------------------------  --------------
# 2020-12-29 19:20:15.002527 CET | [2020_12_29_16_35_15] Iteration #3 | Epoch Duration: 2275.3693327903748
# 2020-12-29 19:20:15.004647 CET | [2020_12_29_16_35_15] Iteration #3 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528]
# ----------------------------------  --------------
# Z mean train                             0.0339766
# Z variance train                         0.576508
# KL Divergence                           56.9053
# KL Loss                                  5.69053
# QF Loss                                 52.3644
# VF Loss                                 12.0436
# Policy Loss                             95.4943
# Q Predictions Mean                    -102.134
# Q Predictions Std                       89.2332
# Q Predictions Max                        0.302954
# Q Predictions Min                     -324.895
# V Predictions Mean                     -93.9269
# V Predictions Std                       87.0649
# V Predictions Max                        5.52123
# V Predictions Min                     -310.816
# Log Pis Mean                            -1.89148
# Log Pis Std                              2.39377
# Log Pis Max                              8.64838
# Log Pis Min                            -11.5841
# Policy mu Mean                          -0.028935
# Policy mu Std                            0.678519
# Policy mu Max                            2.71237
# Policy mu Min                           -2.39298
# Policy log std Mean                     -0.346534
# Policy log std Std                       0.214477
# Policy log std Max                       0.30655
# Policy log std Min                      -1.54427
# Z mean eval                              0.173832
# Z variance eval                          0.0714445
# AverageTrainReturn_all_train_tasks    -138.99
# AverageReturn_all_train_tasks         -135.215
# AverageReturn_all_test_tasks          -136.775
# Number of train steps total          10000
# Number of env steps total           225000
# Number of rollouts total                 0
# Train Time (s)                        1774.49
# (Previous) Eval Time (s)               160.946
# Sample Time (s)                         17.2725
# Epoch Time (s)                        1952.71
# Total Train Time (s)                 11808.4
# Epoch                                    4
# ----------------------------------  --------------
# 2020-12-29 19:52:03.887173 CET | [2020_12_29_16_35_15] Iteration #4 | Epoch Duration: 1908.8789629936218
# 2020-12-29 19:52:03.888723 CET | [2020_12_29_16_35_15] Iteration #4 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939]
# ----------------------------------  -------------
# Z mean train                             0.311705
# Z variance train                         0.643443
# KL Divergence                           63.0048
# KL Loss                                  6.30048
# QF Loss                                 53.1559
# VF Loss                                  9.03706
# Policy Loss                            124.107
# Q Predictions Mean                    -131.452
# Q Predictions Std                      115.3
# Q Predictions Max                        0.40252
# Q Predictions Min                     -426.998
# V Predictions Mean                    -123.509
# V Predictions Std                      113.474
# V Predictions Max                        4.97919
# V Predictions Min                     -427.275
# Log Pis Mean                            -1.79666
# Log Pis Std                              2.51841
# Log Pis Max                              8.76344
# Log Pis Min                            -11.6944
# Policy mu Mean                           0.025985
# Policy mu Std                            0.688519
# Policy mu Max                            2.5558
# Policy mu Min                           -2.55385
# Policy log std Mean                     -0.377883
# Policy log std Std                       0.231698
# Policy log std Max                       0.357822
# Policy log std Min                      -1.84737
# Z mean eval                              0.277315
# Z variance eval                          0.119517
# AverageTrainReturn_all_train_tasks    -108.19
# AverageReturn_all_train_tasks         -168.358
# AverageReturn_all_test_tasks          -126.1
# Number of train steps total          12000
# Number of env steps total           230000
# Number of rollouts total                 0
# Train Time (s)                        1661.58
# (Previous) Eval Time (s)               117.118
# Sample Time (s)                         12.6814
# Epoch Time (s)                        1791.38
# Total Train Time (s)                 13602.3
# Epoch                                    5
# ----------------------------------  -------------
# 2020-12-29 20:21:57.716012 CET | [2020_12_29_16_35_15] Iteration #5 | Epoch Duration: 1793.8249082565308
# 2020-12-29 20:21:57.722084 CET | [2020_12_29_16_35_15] Iteration #5 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934]
# ----------------------------------  --------------
# Z mean train                             0.159594
# Z variance train                         0.63877
# KL Divergence                           70.4645
# KL Loss                                  7.04645
# QF Loss                                 52.1319
# VF Loss                                 10.046
# Policy Loss                            145.266
# Q Predictions Mean                    -153.667
# Q Predictions Std                      139.672
# Q Predictions Max                        0.507964
# Q Predictions Min                     -565.347
# V Predictions Mean                    -144.46
# V Predictions Std                      137.55
# V Predictions Max                        5.05841
# V Predictions Min                     -563.696
# Log Pis Mean                            -1.72453
# Log Pis Std                              2.44754
# Log Pis Max                              8.97011
# Log Pis Min                            -10.3187
# Policy mu Mean                          -0.0114968
# Policy mu Std                            0.698486
# Policy mu Max                            2.34076
# Policy mu Min                           -3.24364
# Policy log std Mean                     -0.375292
# Policy log std Std                       0.238411
# Policy log std Max                       0.273413
# Policy log std Min                      -1.87204
# Z mean eval                              0.21275
# Z variance eval                          0.0886949
# AverageTrainReturn_all_train_tasks     -82.4053
# AverageReturn_all_train_tasks          -91.9214
# AverageReturn_all_test_tasks          -140.349
# Number of train steps total          14000
# Number of env steps total           235000
# Number of rollouts total                 0
# Train Time (s)                        1568.4
# (Previous) Eval Time (s)               119.559
# Sample Time (s)                         11.3761
# Epoch Time (s)                        1699.34
# Total Train Time (s)                 15263.8
# Epoch                                    6
# ----------------------------------  --------------
# 2020-12-29 20:49:39.226403 CET | [2020_12_29_16_35_15] Iteration #6 | Epoch Duration: 1661.5016479492188
# 2020-12-29 20:49:39.227774 CET | [2020_12_29_16_35_15] Iteration #6 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692]
# ----------------------------------  --------------
# Z mean train                             0.0533855
# Z variance train                         0.592025
# KL Divergence                           49.8966
# KL Loss                                  4.98966
# QF Loss                                 32.9631
# VF Loss                                  7.46208
# Policy Loss                             60.8565
# Q Predictions Mean                     -67.3031
# Q Predictions Std                       70.2118
# Q Predictions Max                        0.60479
# Q Predictions Min                     -355.06
# V Predictions Mean                     -60.3706
# V Predictions Std                       68.7536
# V Predictions Max                        5.75492
# V Predictions Min                     -351.522
# Log Pis Mean                            -2.42562
# Log Pis Std                              1.94535
# Log Pis Max                              8.02843
# Log Pis Min                            -11.6892
# Policy mu Mean                           0.045607
# Policy mu Std                            0.550138
# Policy mu Max                            2.28968
# Policy mu Min                           -2.09052
# Policy log std Mean                     -0.370056
# Policy log std Std                       0.215163
# Policy log std Max                       0.129756
# Policy log std Min                      -1.81332
# Z mean eval                              0.356424
# Z variance eval                          0.171308
# AverageTrainReturn_all_train_tasks     -86.0413
# AverageReturn_all_train_tasks         -114.533
# AverageReturn_all_test_tasks          -126.199
# Number of train steps total          16000
# Number of env steps total           240000
# Number of rollouts total                 0
# Train Time (s)                        1566.96
# (Previous) Eval Time (s)                81.7241
# Sample Time (s)                          7.65747
# Epoch Time (s)                        1656.34
# Total Train Time (s)                 16945.3
# Epoch                                    7
# ----------------------------------  --------------
# 2020-12-29 21:17:40.764960 CET | [2020_12_29_16_35_15] Iteration #7 | Epoch Duration: 1681.534873008728
# 2020-12-29 21:17:40.766703 CET | [2020_12_29_16_35_15] Iteration #7 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883]
# ----------------------------------  --------------
# Z mean train                             0.224054
# Z variance train                         0.597505
# KL Divergence                           50.4032
# KL Loss                                  5.04032
# QF Loss                                 33.6968
# VF Loss                                  6.35416
# Policy Loss                             67.3822
# Q Predictions Mean                     -74.28
# Q Predictions Std                       71.3119
# Q Predictions Max                        0.709198
# Q Predictions Min                     -404.415
# V Predictions Mean                     -67.3449
# V Predictions Std                       69.4297
# V Predictions Max                        5.96873
# V Predictions Min                     -398.347
# Log Pis Mean                            -2.23019
# Log Pis Std                              2.07159
# Log Pis Max                              7.14288
# Log Pis Min                             -9.33073
# Policy mu Mean                           0.0252662
# Policy mu Std                            0.589927
# Policy mu Max                            2.67714
# Policy mu Min                           -2.05268
# Policy log std Mean                     -0.385417
# Policy log std Std                       0.229472
# Policy log std Max                       0.145406
# Policy log std Min                      -1.78796
# Z mean eval                              0.116586
# Z variance eval                          0.146868
# AverageTrainReturn_all_train_tasks     -96.4912
# AverageReturn_all_train_tasks         -115.386
# AverageReturn_all_test_tasks          -103.169
# Number of train steps total          18000
# Number of env steps total           245000
# Number of rollouts total                 0
# Train Time (s)                        1633.72
# (Previous) Eval Time (s)               106.919
# Sample Time (s)                         10.1278
# Epoch Time (s)                        1750.77
# Total Train Time (s)                 18698.5
# Epoch                                    8
# ----------------------------------  --------------
# 2020-12-29 21:46:54.024012 CET | [2020_12_29_16_35_15] Iteration #8 | Epoch Duration: 1753.2549877166748
# 2020-12-29 21:46:54.044260 CET | [2020_12_29_16_35_15] Iteration #8 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948]
# ----------------------------------  ---------------
# Z mean train                             0.054854
# Z variance train                         0.553588
# KL Divergence                           56.8321
# KL Loss                                  5.68321
# QF Loss                                 44.9747
# VF Loss                                 10.3738
# Policy Loss                            124.699
# Q Predictions Mean                    -132.869
# Q Predictions Std                      112.147
# Q Predictions Max                        0.814448
# Q Predictions Min                     -732.504
# V Predictions Mean                    -123.812
# V Predictions Std                      111.075
# V Predictions Max                        5.83189
# V Predictions Min                     -730.23
# Log Pis Mean                            -1.76366
# Log Pis Std                              2.32998
# Log Pis Max                              7.9481
# Log Pis Min                            -11.4147
# Policy mu Mean                          -0.00842328
# Policy mu Std                            0.669452
# Policy mu Max                            2.61397
# Policy mu Min                           -2.35218
# Policy log std Mean                     -0.402404
# Policy log std Std                       0.245831
# Policy log std Max                       0.0727634
# Policy log std Min                      -1.86043
# Z mean eval                              0.367615
# Z variance eval                          0.12342
# AverageTrainReturn_all_train_tasks     -84.0409
# AverageReturn_all_train_tasks          -92.5761
# AverageReturn_all_test_tasks           -98.5244
# Number of train steps total          20000
# Number of env steps total           250000
# Number of rollouts total                 0
# Train Time (s)                        1633.65
# (Previous) Eval Time (s)               109.4
# Sample Time (s)                          9.38843
# Epoch Time (s)                        1752.43
# Total Train Time (s)                 20457.5
# Epoch                                    9
# ----------------------------------  ---------------
# 2020-12-29 22:16:13.040576 CET | [2020_12_29_16_35_15] Iteration #9 | Epoch Duration: 1758.9936997890472
# 2020-12-29 22:16:13.042692 CET | [2020_12_29_16_35_15] Iteration #9 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714]
# ----------------------------------  --------------
# Z mean train                             0.286143
# Z variance train                         0.548354
# KL Divergence                           54.4056
# KL Loss                                  5.44056
# QF Loss                                 41.8482
# VF Loss                                  9.25778
# Policy Loss                            105.171
# Q Predictions Mean                    -112.442
# Q Predictions Std                      110.558
# Q Predictions Max                        0.915184
# Q Predictions Min                     -731.291
# V Predictions Mean                    -105.109
# V Predictions Std                      109.738
# V Predictions Max                        5.72042
# V Predictions Min                     -731.337
# Log Pis Mean                            -2.02244
# Log Pis Std                              2.12854
# Log Pis Max                              9.66628
# Log Pis Min                             -9.60878
# Policy mu Mean                           0.0133468
# Policy mu Std                            0.630439
# Policy mu Max                            2.27757
# Policy mu Min                           -2.87624
# Policy log std Mean                     -0.405639
# Policy log std Std                       0.227891
# Policy log std Max                       0.130197
# Policy log std Min                      -1.83979
# Z mean eval                              0.3789
# Z variance eval                          0.135977
# AverageTrainReturn_all_train_tasks     -74.6979
# AverageReturn_all_train_tasks          -93.9099
# AverageReturn_all_test_tasks          -111.286
# Number of train steps total          22000
# Number of env steps total           255000
# Number of rollouts total                 0
# Train Time (s)                        1491.62
# (Previous) Eval Time (s)               115.957
# Sample Time (s)                         12.6073
# Epoch Time (s)                        1620.19
# Total Train Time (s)                 22073.6
# Epoch                                   10
# ----------------------------------  --------------
# 2020-12-29 22:43:09.061854 CET | [2020_12_29_16_35_15] Iteration #10 | Epoch Duration: 1616.0159394741058
# 2020-12-29 22:43:09.066230 CET | [2020_12_29_16_35_15] Iteration #10 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174]
# ----------------------------------  ---------------
# Z mean train                             0.0666869
# Z variance train                         0.663811
# KL Divergence                           69.7734
# KL Loss                                  6.97734
# QF Loss                                 44.4216
# VF Loss                                 11.0309
# Policy Loss                            150.979
# Q Predictions Mean                    -157.682
# Q Predictions Std                      142.878
# Q Predictions Max                        1.01079
# Q Predictions Min                     -751.267
# V Predictions Mean                    -151.837
# V Predictions Std                      142.507
# V Predictions Max                        6.22153
# V Predictions Min                     -744.811
# Log Pis Mean                            -1.7286
# Log Pis Std                              2.24429
# Log Pis Max                              8.57251
# Log Pis Min                            -10.3752
# Policy mu Mean                          -0.00866595
# Policy mu Std                            0.669989
# Policy mu Max                            2.71926
# Policy mu Min                           -2.84425
# Policy log std Mean                     -0.422533
# Policy log std Std                       0.23976
# Policy log std Max                       0.0848341
# Policy log std Min                      -1.9248
# Z mean eval                              0.463098
# Z variance eval                          0.14336
# AverageTrainReturn_all_train_tasks     -71.624
# AverageReturn_all_train_tasks          -80.2519
# AverageReturn_all_test_tasks           -85.3363
# Number of train steps total          24000
# Number of env steps total           260000
# Number of rollouts total                 0
# Train Time (s)                        1615.88
# (Previous) Eval Time (s)               111.784
# Sample Time (s)                          8.78381
# Epoch Time (s)                        1736.45
# Total Train Time (s)                 23803.5
# Epoch                                   11
# ----------------------------------  ---------------
# 2020-12-29 23:11:58.966030 CET | [2020_12_29_16_35_15] Iteration #11 | Epoch Duration: 1729.8974351882935
# 2020-12-29 23:11:58.972641 CET | [2020_12_29_16_35_15] Iteration #11 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944]
# ----------------------------------  ---------------
# Z mean train                             0.261389
# Z variance train                         0.517467
# KL Divergence                           68.4131
# KL Loss                                  6.84131
# QF Loss                                 35.6409
# VF Loss                                 13.2427
# Policy Loss                            138.51
# Q Predictions Mean                    -145.596
# Q Predictions Std                      150.255
# Q Predictions Max                        1.10645
# Q Predictions Min                     -801.359
# V Predictions Mean                    -136.621
# V Predictions Std                      147.608
# V Predictions Max                        6.08517
# V Predictions Min                     -796.706
# Log Pis Mean                            -2.19769
# Log Pis Std                              2.16889
# Log Pis Max                              9.54826
# Log Pis Min                             -9.3361
# Policy mu Mean                          -0.00459216
# Policy mu Std                            0.611683
# Policy mu Max                            2.55551
# Policy mu Min                           -2.62483
# Policy log std Mean                     -0.361092
# Policy log std Std                       0.222409
# Policy log std Max                       0.177198
# Policy log std Min                      -1.76324
# Z mean eval                              0.38719
# Z variance eval                          0.144725
# AverageTrainReturn_all_train_tasks     -74.9021
# AverageReturn_all_train_tasks          -73.5337
# AverageReturn_all_test_tasks           -75.7445
# Number of train steps total          26000
# Number of env steps total           265000
# Number of rollouts total                 0
# Train Time (s)                        1618.69
# (Previous) Eval Time (s)               105.229
# Sample Time (s)                         11.1751
# Epoch Time (s)                        1735.09
# Total Train Time (s)                 25545.4
# Epoch                                   12
# ----------------------------------  ---------------
# 2020-12-29 23:41:00.914052 CET | [2020_12_29_16_35_15] Iteration #12 | Epoch Duration: 1741.9319541454315
# 2020-12-29 23:41:00.915727 CET | [2020_12_29_16_35_15] Iteration #12 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438]
# ----------------------------------  --------------
# Z mean train                             0.154378
# Z variance train                         0.578107
# KL Divergence                           60.1504
# KL Loss                                  6.01504
# QF Loss                                 29.3972
# VF Loss                                  7.85784
# Policy Loss                             62.1899
# Q Predictions Mean                     -68.8758
# Q Predictions Std                       79.5809
# Q Predictions Max                        1.2008
# Q Predictions Min                     -602.739
# V Predictions Mean                     -62.9465
# V Predictions Std                       78.7894
# V Predictions Max                        5.9951
# V Predictions Min                     -599.534
# Log Pis Mean                            -2.47877
# Log Pis Std                              1.92829
# Log Pis Max                              7.00536
# Log Pis Min                             -9.71386
# Policy mu Mean                           0.0482523
# Policy mu Std                            0.534263
# Policy mu Max                            2.41224
# Policy mu Min                           -2.1839
# Policy log std Mean                     -0.384742
# Policy log std Std                       0.226041
# Policy log std Max                       0.0569306
# Policy log std Min                      -1.87726
# Z mean eval                              0.3464
# Z variance eval                          0.119236
# AverageTrainReturn_all_train_tasks     -75.7713
# AverageReturn_all_train_tasks          -92.3541
# AverageReturn_all_test_tasks           -80.6583
# Number of train steps total          28000
# Number of env steps total           270000
# Number of rollouts total                 0
# Train Time (s)                        1525.83
# (Previous) Eval Time (s)               112.061
# Sample Time (s)                         10.3067
# Epoch Time (s)                        1648.2
# Total Train Time (s)                 27161.5
# Epoch                                   13
# ----------------------------------  --------------
# 2020-12-30 00:07:56.981959 CET | [2020_12_29_16_35_15] Iteration #13 | Epoch Duration: 1616.0638563632965
# 2020-12-30 00:07:56.996153 CET | [2020_12_29_16_35_15] Iteration #13 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855]
# ----------------------------------  ---------------
# Z mean train                             0.19434
# Z variance train                         0.65772
# KL Divergence                           67.2913
# KL Loss                                  6.72913
# QF Loss                                 43.1636
# VF Loss                                 11.3482
# Policy Loss                            176.281
# Q Predictions Mean                    -184.474
# Q Predictions Std                      155.472
# Q Predictions Max                        1.30074
# Q Predictions Min                     -870.668
# V Predictions Mean                    -176.61
# V Predictions Std                      153.882
# V Predictions Max                        5.9616
# V Predictions Min                     -867.076
# Log Pis Mean                            -1.63551
# Log Pis Std                              2.31513
# Log Pis Max                              8.74121
# Log Pis Min                            -10.0036
# Policy mu Mean                          -0.00164533
# Policy mu Std                            0.689882
# Policy mu Max                            2.63596
# Policy mu Min                           -2.34682
# Policy log std Mean                     -0.428686
# Policy log std Std                       0.238609
# Policy log std Max                       0.090194
# Policy log std Min                      -1.90217
# Z mean eval                              0.381962
# Z variance eval                          0.140485
# AverageTrainReturn_all_train_tasks     -75.4677
# AverageReturn_all_train_tasks          -83.2335
# AverageReturn_all_test_tasks           -83.3692
# Number of train steps total          30000
# Number of env steps total           275000
# Number of rollouts total                 0
# Train Time (s)                        1547.75
# (Previous) Eval Time (s)                79.9254
# Sample Time (s)                          8.67172
# Epoch Time (s)                        1636.34
# Total Train Time (s)                 28831.5
# Epoch                                   14
# ----------------------------------  ---------------
# 2020-12-30 00:35:46.960747 CET | [2020_12_29_16_35_15] Iteration #14 | Epoch Duration: 1669.9607071876526
# 2020-12-30 00:35:46.976386 CET | [2020_12_29_16_35_15] Iteration #14 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127]
# ----------------------------------  --------------
# Z mean train                             0.654911
# Z variance train                         0.712292
# KL Divergence                           61.1409
# KL Loss                                  6.11409
# QF Loss                                 41.5631
# VF Loss                                 10.3872
# Policy Loss                            155.8
# Q Predictions Mean                    -163.805
# Q Predictions Std                      137.337
# Q Predictions Max                        1.40468
# Q Predictions Min                     -640.482
# V Predictions Mean                    -155.996
# V Predictions Std                      136.408
# V Predictions Max                        6.24912
# V Predictions Min                     -646.583
# Log Pis Mean                            -1.64617
# Log Pis Std                              2.32759
# Log Pis Max                              8.34925
# Log Pis Min                             -9.77871
# Policy mu Mean                          -0.0311285
# Policy mu Std                            0.688374
# Policy mu Max                            2.44725
# Policy mu Min                           -2.35932
# Policy log std Mean                     -0.435064
# Policy log std Std                       0.244353
# Policy log std Max                       0.0601988
# Policy log std Min                      -2.10161
# Z mean eval                              0.399028
# Z variance eval                          0.131675
# AverageTrainReturn_all_train_tasks     -71.0503
# AverageReturn_all_train_tasks          -80.9008
# AverageReturn_all_test_tasks           -70.5686
# Number of train steps total          32000
# Number of env steps total           280000
# Number of rollouts total                 0
# Train Time (s)                        1621.12
# (Previous) Eval Time (s)               113.54
# Sample Time (s)                         10.7835
# Epoch Time (s)                        1745.45
# Total Train Time (s)                 30570.3
# Epoch                                   15
# ----------------------------------  --------------
# 2020-12-30 01:04:45.738440 CET | [2020_12_29_16_35_15] Iteration #15 | Epoch Duration: 1738.7590181827545
# 2020-12-30 01:04:45.740443 CET | [2020_12_29_16_35_15] Iteration #15 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951]
# ----------------------------------  --------------
# Z mean train                             0.658457
# Z variance train                         0.815213
# KL Divergence                           72.9082
# KL Loss                                  7.29082
# QF Loss                                 35.2891
# VF Loss                                  9.48695
# Policy Loss                            139.711
# Q Predictions Mean                    -146.752
# Q Predictions Std                      188.818
# Q Predictions Max                        1.50095
# Q Predictions Min                     -966.131
# V Predictions Mean                    -138.893
# V Predictions Std                      186.725
# V Predictions Max                        6.35446
# V Predictions Min                     -966.34
# Log Pis Mean                            -2.17729
# Log Pis Std                              2.19057
# Log Pis Max                              7.97829
# Log Pis Min                             -8.76874
# Policy mu Mean                           0.0138331
# Policy mu Std                            0.599862
# Policy mu Max                            2.41374
# Policy mu Min                           -2.27685
# Policy log std Mean                     -0.373674
# Policy log std Std                       0.237919
# Policy log std Max                       0.112555
# Policy log std Min                      -1.97735
# Z mean eval                              0.333095
# Z variance eval                          0.115077
# AverageTrainReturn_all_train_tasks     -72.0929
# AverageReturn_all_train_tasks          -80.4005
# AverageReturn_all_test_tasks           -68.6483
# Number of train steps total          34000
# Number of env steps total           285000
# Number of rollouts total                 0
# Train Time (s)                        1625.01
# (Previous) Eval Time (s)               106.85
# Sample Time (s)                          7.9771
# Epoch Time (s)                        1739.83
# Total Train Time (s)                 32309.3
# Epoch                                   16
# ----------------------------------  --------------
# 2020-12-30 01:33:44.767483 CET | [2020_12_29_16_35_15] Iteration #16 | Epoch Duration: 1739.024486541748
# 2020-12-30 01:33:44.769404 CET | [2020_12_29_16_35_15] Iteration #16 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376]
# ----------------------------------  -------------
# Z mean train                             0.164376
# Z variance train                         0.578178
# KL Divergence                           70.8402
# KL Loss                                  7.08402
# QF Loss                                 46.1979
# VF Loss                                 11.6324
# Policy Loss                            207.088
# Q Predictions Mean                    -214.53
# Q Predictions Std                      189.335
# Q Predictions Max                        1.60555
# Q Predictions Min                    -1013.42
# V Predictions Mean                    -207.001
# V Predictions Std                      188.535
# V Predictions Max                        6.76972
# V Predictions Min                     -992.432
# Log Pis Mean                            -1.76058
# Log Pis Std                              2.33308
# Log Pis Max                              8.78037
# Log Pis Min                            -11.7439
# Policy mu Mean                           0.017683
# Policy mu Std                            0.67102
# Policy mu Max                            3.05067
# Policy mu Min                           -2.55634
# Policy log std Mean                     -0.413006
# Policy log std Std                       0.244326
# Policy log std Max                       0.142434
# Policy log std Min                      -1.92903
# Z mean eval                              0.330941
# Z variance eval                          0.146646
# AverageTrainReturn_all_train_tasks     -62.9644
# AverageReturn_all_train_tasks          -68.0007
# AverageReturn_all_test_tasks           -64.6674
# Number of train steps total          36000
# Number of env steps total           290000
# Number of rollouts total                 0
# Train Time (s)                        1473.24
# (Previous) Eval Time (s)               106.039
# Sample Time (s)                          9.26888
# Epoch Time (s)                        1588.55
# Total Train Time (s)                 33905.2
# Epoch                                   17
# ----------------------------------  -------------
# 2020-12-30 02:00:20.726013 CET | [2020_12_29_16_35_15] Iteration #17 | Epoch Duration: 1595.9536802768707
# 2020-12-30 02:00:20.735660 CET | [2020_12_29_16_35_15] Iteration #17 | Started Training: True
# ...
# V Predictions Std                      155.232
# V Predictions Max                        8.13244
# V Predictions Min                    -1112.24
# Log Pis Mean                            -2.10472
# Log Pis Std                              2.27176
# Log Pis Max                             10.635
# Log Pis Min                            -11.4997
# Policy mu Mean                           0.0138631
# Policy mu Std                            0.609803
# Policy mu Max                            2.67825
# Policy mu Min                           -2.5395
# Policy log std Mean                     -0.399509
# Policy log std Std                       0.237575
# Policy log std Max                       0.125999
# Policy log std Min                      -2.01615
# Z mean eval                              0.342315
# Z variance eval                          0.11872
# AverageTrainReturn_all_train_tasks     -59.9119
# AverageReturn_all_train_tasks          -58.5771
# AverageReturn_all_test_tasks           -68.6278
# Number of train steps total          54000
# Number of env steps total           335000
# Number of rollouts total                 0
# Train Time (s)                        1628.21
# (Previous) Eval Time (s)               107.483
# Sample Time (s)                         10.9551
# Epoch Time (s)                        1746.65
# Total Train Time (s)                 49286.4
# Epoch                                   26
# ----------------------------------  --------------
# 2020-12-30 06:16:41.884506 CET | [2020_12_29_16_35_15] Iteration #26 | Epoch Duration: 1751.0636885166168
# 2020-12-30 06:16:41.887786 CET | [2020_12_29_16_35_15] Iteration #26 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376, -68.77288061437083, -65.68487037920701, -66.84640300449469, -65.55570608492596, -68.90744423205724, -60.94047704276206, -67.30722624263971, -67.22452844380275, -68.6277523747863, -60.68539688344551]
# ----------------------------------  ---------------
# Z mean train                             0.101926
# Z variance train                         0.645496
# KL Divergence                           57.7367
# KL Loss                                  5.77367
# QF Loss                                 30.6376
# VF Loss                                  7.68547
# Policy Loss                            120.81
# Q Predictions Mean                    -127.495
# Q Predictions Std                      151.456
# Q Predictions Max                        2.8678
# Q Predictions Min                    -1118.48
# V Predictions Mean                    -120.192
# V Predictions Std                      150.704
# V Predictions Max                        7.98445
# V Predictions Min                    -1111.23
# Log Pis Mean                            -1.89429
# Log Pis Std                              2.22274
# Log Pis Max                             11.088
# Log Pis Min                             -9.06615
# Policy mu Mean                          -0.00258367
# Policy mu Std                            0.633058
# Policy mu Max                            2.82193
# Policy mu Min                           -3.0175
# Policy log std Mean                     -0.425765
# Policy log std Std                       0.238717
# Policy log std Max                       0.160485
# Policy log std Min                      -2.03108
# Z mean eval                              0.276872
# Z variance eval                          0.110938
# AverageTrainReturn_all_train_tasks     -65.4058
# AverageReturn_all_train_tasks          -67.3519
# AverageReturn_all_test_tasks           -60.6854
# Number of train steps total          56000
# Number of env steps total           340000
# Number of rollouts total                 0
# Train Time (s)                        1564.21
# (Previous) Eval Time (s)               111.897
# Sample Time (s)                          9.8881
# Epoch Time (s)                        1686
# Total Train Time (s)                 50941.5
# Epoch                                   27
# ----------------------------------  ---------------
# 2020-12-30 06:44:17.030291 CET | [2020_12_29_16_35_15] Iteration #27 | Epoch Duration: 1655.1394717693329
# 2020-12-30 06:44:17.042691 CET | [2020_12_29_16_35_15] Iteration #27 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376, -68.77288061437083, -65.68487037920701, -66.84640300449469, -65.55570608492596, -68.90744423205724, -60.94047704276206, -67.30722624263971, -67.22452844380275, -68.6277523747863, -60.68539688344551, -66.78125795186726]
# ----------------------------------  --------------
# Z mean train                             0.0862321
# Z variance train                         0.76346
# KL Divergence                           57.0907
# KL Loss                                  5.70907
# QF Loss                                 19.747
# VF Loss                                  5.8621
# Policy Loss                             68.3298
# Q Predictions Mean                     -74.1626
# Q Predictions Std                      129.852
# Q Predictions Max                        3.00042
# Q Predictions Min                     -945.425
# V Predictions Mean                     -68.3045
# V Predictions Std                      129.544
# V Predictions Max                        8.16795
# V Predictions Min                     -932.761
# Log Pis Mean                            -2.52069
# Log Pis Std                              1.9103
# Log Pis Max                              9.57804
# Log Pis Min                             -8.29133
# Policy mu Mean                           0.0325953
# Policy mu Std                            0.539459
# Policy mu Max                            2.31379
# Policy mu Min                           -2.60809
# Policy log std Mean                     -0.384504
# Policy log std Std                       0.216739
# Policy log std Max                       0.248059
# Policy log std Min                      -2.10332
# Z mean eval                              0.407483
# Z variance eval                          0.12316
# AverageTrainReturn_all_train_tasks     -55.4207
# AverageReturn_all_train_tasks          -58.1052
# AverageReturn_all_test_tasks           -66.7813
# Number of train steps total          58000
# Number of env steps total           345000
# Number of rollouts total                 0
# Train Time (s)                        1563.81
# (Previous) Eval Time (s)                81.0358
# Sample Time (s)                          6.05671
# Epoch Time (s)                        1650.91
# Total Train Time (s)                 52612.9
# Epoch                                   28
# ----------------------------------  --------------
# 2020-12-30 07:12:08.452446 CET | [2020_12_29_16_35_15] Iteration #28 | Epoch Duration: 1671.4055936336517
# 2020-12-30 07:12:08.465903 CET | [2020_12_29_16_35_15] Iteration #28 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376, -68.77288061437083, -65.68487037920701, -66.84640300449469, -65.55570608492596, -68.90744423205724, -60.94047704276206, -67.30722624263971, -67.22452844380275, -68.6277523747863, -60.68539688344551, -66.78125795186726, -65.88723522759936]
# ----------------------------------  --------------
# Z mean train                             0.0290152
# Z variance train                         0.519451
# KL Divergence                           62.5302
# KL Loss                                  6.25302
# QF Loss                                 26.2346
# VF Loss                                  7.31484
# Policy Loss                             78.6838
# Q Predictions Mean                     -85.015
# Q Predictions Std                      109.951
# Q Predictions Max                        3.15125
# Q Predictions Min                     -769.191
# V Predictions Mean                     -78.0329
# V Predictions Std                      108.977
# V Predictions Max                        8.65803
# V Predictions Min                     -767.247
# Log Pis Mean                            -2.32894
# Log Pis Std                              2.10965
# Log Pis Max                             13.165
# Log Pis Min                            -11.6908
# Policy mu Mean                           0.0114887
# Policy mu Std                            0.576569
# Policy mu Max                            2.53925
# Policy mu Min                           -2.46597
# Policy log std Mean                     -0.381258
# Policy log std Std                       0.237281
# Policy log std Max                       0.171444
# Policy log std Min                      -1.99278
# Z mean eval                              0.316236
# Z variance eval                          0.122594
# AverageTrainReturn_all_train_tasks     -69.2549
# AverageReturn_all_train_tasks          -76.9061
# AverageReturn_all_test_tasks           -65.8872
# Number of train steps total          60000
# Number of env steps total           350000
# Number of rollouts total                 0
# Train Time (s)                        1613.51
# (Previous) Eval Time (s)               101.533
# Sample Time (s)                         14.0897
# Epoch Time (s)                        1729.13
# Total Train Time (s)                 54356.2
# Epoch                                   29
# ----------------------------------  --------------
# 2020-12-30 07:41:11.724409 CET | [2020_12_29_16_35_15] Iteration #29 | Epoch Duration: 1743.254290819168
# 2020-12-30 07:41:11.726033 CET | [2020_12_29_16_35_15] Iteration #29 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376, -68.77288061437083, -65.68487037920701, -66.84640300449469, -65.55570608492596, -68.90744423205724, -60.94047704276206, -67.30722624263971, -67.22452844380275, -68.6277523747863, -60.68539688344551, -66.78125795186726, -65.88723522759936, -63.46093393787699]
# ----------------------------------  --------------
# Z mean train                             0.0190543
# Z variance train                         0.570636
# KL Divergence                           56.0272
# KL Loss                                  5.60272
# QF Loss                                 32.1456
# VF Loss                                  9.11643
# Policy Loss                             95.2635
# Q Predictions Mean                    -102.347
# Q Predictions Std                      180.795
# Q Predictions Max                        3.28289
# Q Predictions Min                    -1244.4
# V Predictions Mean                     -94.7556
# V Predictions Std                      178.827
# V Predictions Max                        8.58388
# V Predictions Min                    -1223.9
# Log Pis Mean                            -2.28873
# Log Pis Std                              2.14483
# Log Pis Max                             13.1179
# Log Pis Min                             -9.03373
# Policy mu Mean                           0.0386272
# Policy mu Std                            0.580308
# Policy mu Max                            3.77914
# Policy mu Min                           -2.96557
# Policy log std Mean                     -0.385678
# Policy log std Std                       0.224101
# Policy log std Max                       0.163717
# Policy log std Min                      -1.97036
# Z mean eval                              0.317558
# Z variance eval                          0.124142
# AverageTrainReturn_all_train_tasks     -59.5368
# AverageReturn_all_train_tasks          -58.7075
# AverageReturn_all_test_tasks           -63.4609
# Number of train steps total          62000
# Number of env steps total           355000
# Number of rollouts total                 0
# Train Time (s)                        1627.76
# (Previous) Eval Time (s)               115.651
# Sample Time (s)                         11.6286
# Epoch Time (s)                        1755.04
# Total Train Time (s)                 56109.6
# Epoch                                   30
# ----------------------------------  --------------
# 2020-12-30 08:10:25.210666 CET | [2020_12_29_16_35_15] Iteration #30 | Epoch Duration: 1753.4825456142426
# 2020-12-30 08:10:25.227265 CET | [2020_12_29_16_35_15] Iteration #30 | Started Training: True
# [-274.0129071805964, -230.5835926598467, -253.69840493585428, -150.44784922840003, -136.77510359879528, -126.0996444202939, -140.34931504838934, -126.19928426976692, -103.16878583327883, -98.5243732837948, -111.28630985642714, -85.33634599694174, -75.7445294857944, -80.65833918667438, -83.36920843009855, -70.56862311006127, -68.64829346671951, -64.66744328437376, -68.77288061437083, -65.68487037920701, -66.84640300449469, -65.55570608492596, -68.90744423205724, -60.94047704276206, -67.30722624263971, -67.22452844380275, -68.6277523747863, -60.68539688344551, -66.78125795186726, -65.88723522759936, -63.46093393787699, -69.03198265485501]
# ----------------------------------  ---------------
# Z mean train                             0.327072
# Z variance train                         0.803401
# KL Divergence                           67.5808
# KL Loss                                  6.75808
# QF Loss                                 18.5274
# VF Loss                                  5.92266
# Policy Loss                             67.2719
# Q Predictions Mean                     -73.4778
# Q Predictions Std                      124.928
# Q Predictions Max                        3.43086
# Q Predictions Min                    -1056.62
# V Predictions Mean                     -67.4576
# V Predictions Std                      123.593
# V Predictions Max                        8.82628
# V Predictions Min                    -1057.06
# Log Pis Mean                            -2.60514
# Log Pis Std                              2.07069
# Log Pis Max                             14.097
# Log Pis Min                            -11.2853
# Policy mu Mean                           0.00759518
# Policy mu Std                            0.532008
# Policy mu Max                            2.63243
# Policy mu Min                           -2.79966
# Policy log std Mean                     -0.352105
# Policy log std Std                       0.22551
# Policy log std Max                       0.0469297
# Policy log std Min                      -2.07324
# Z mean eval                              0.344856
# Z variance eval                          0.139713
# AverageTrainReturn_all_train_tasks     -63.5813
# AverageReturn_all_train_tasks          -67.9411
# AverageReturn_all_test_tasks           -69.032
# Number of train steps total          64000
# Number of env steps total           360000
# Number of rollouts total                 0
# Train Time (s)                        1475.5
# (Previous) Eval Time (s)               114.093
# Sample Time (s)                         10.9148
# Epoch Time (s)                        1600.51
# Total Train Time (s)                 57699.5
# Epoch                                   31
# ----------------------------------  ---------------
# 2020-12-30 08:36:55.011369 CET | [2020_12_29_16_35_15] Iteration #31 | Epoch Duration: 1589.7790400981903
# 2020-12-30 08:36:55.012956 CET | [2020_12_29_16_35_15] Iteration #31 | Started Training: True

# %%
import sim_policy

# %%
sim_policy.sim_policy(variant=)
